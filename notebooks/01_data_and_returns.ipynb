# %% [markdown]
# # Data Download and Returns
#
# Loads ETF prices from Yahoo Finance (cached) and computes log returns.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
from src.data.loader import load_prices_and_returns
prices, returns = load_prices_and_returns()
prices.tail()
# Out:
# Ticker            EEM         GLD        IEF         QQQ         SPY  \
# Date
# 2024-12-24  41.635063  241.440002  88.818146  527.285828  594.320801
# 2024-12-26  41.488602  243.070007  88.885536  526.927612  594.360352
# 2024-12-27  41.303078  241.399994  88.654472  519.923157  588.103821
# 2024-12-30  40.971088  240.630005  89.174377  513.008179  581.392578
# 2024-12-31  40.834389  242.130005  89.010689  508.650360  579.277466
#
# Ticker            TLT        VNQ
# Date
# 2024-12-24  84.125931  86.025826
# 2024-12-26  84.078049  86.256729
# 2024-12-27  83.388748  85.390793
# 2024-12-30  84.058922  84.967445
# 2024-12-31  83.608940  85.708298

# %%
returns.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# EEM     3269.0  0.000107  0.012692 -0.133294 -0.006855  0.000693  0.007459
# GLD     3269.0  0.000135  0.009438 -0.091905 -0.004782  0.000388  0.005095
# IEF     3269.0  0.000040  0.004079 -0.025392 -0.002333  0.000188  0.002430
# QQQ     3269.0  0.000707  0.012788 -0.127592 -0.004568  0.001164  0.007322
# SPY     3269.0  0.000539  0.010386 -0.115886 -0.003582  0.000652  0.005586
# TLT     3269.0  0.000007  0.009300 -0.069010 -0.005634  0.000475  0.005629
# VNQ     3269.0  0.000286  0.012300 -0.195136 -0.005280  0.000737  0.006704
#
#              max
# Ticker
# EEM     0.077451
# GLD     0.047874
# IEF     0.026073
# QQQ     0.081309
# SPY     0.086731
# TLT     0.072503
# VNQ     0.086147

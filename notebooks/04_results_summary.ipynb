# %% [markdown]
# # Results Summary
#
# Load metrics and show key figures saved in reports/figures.

# %%
import pandas as pd
from pathlib import Path

metrics_path = Path('reports/metrics.csv')
if metrics_path.exists():
    metrics = pd.read_csv(metrics_path, index_col=0)
    display(metrics)
else:
    print('Run the CLI first to generate metrics and figures.')
# Out:
# Run the CLI first to generate metrics and figures.

# %% [markdown]
# Figures (after running the CLI):
# - reports/figures/cumulative_returns.png
# - reports/figures/drawdowns.png
# - reports/figures/rolling_vol.png
# - reports/figures/weights_risk_parity.png
# - reports/figures/weights_min_var.png
# - reports/figures/turnover.png
# - reports/figures/vol_target_diagnostic.png

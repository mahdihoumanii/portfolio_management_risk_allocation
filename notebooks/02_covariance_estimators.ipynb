# %% [markdown]
# # Covariance Estimators
#
# Sample, EWMA, and shrinkage covariance matrices on rolling returns.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
import pandas as pd
from src.data.loader import load_prices_and_returns
from src.strategies.covariance import sample_covariance, ewma_covariance, shrinkage_covariance

_, returns = load_prices_and_returns()
window = returns.iloc[-252:]
sample = sample_covariance(window)
ewma = ewma_covariance(window)
shrink = shrinkage_covariance(window)
pd.DataFrame({"sample_trace": [sample.trace()], "ewma_trace": [ewma.trace()], "shrink_trace": [shrink.trace()]})
# Out:
#    sample_trace  ewma_trace  shrink_trace
# 0      0.000578    0.000611      0.000578

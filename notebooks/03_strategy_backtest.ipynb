# %% [markdown]
# # Strategy Backtest
#
# Run the walk-forward backtest and inspect metrics.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
from src.data.loader import load_prices_and_returns
from src.strategies.backtest import run_backtest

_, returns = load_prices_and_returns()
res = run_backtest(returns, window=252, rebalance='monthly', tc_bps=5.0)
res.metrics
# Out:
#                    CAGR       Vol    Sharpe   Sortino  MaxDrawdown    Calmar  \
# equal_weight   0.058282  0.104990  0.555119  0.684907    -0.269031  0.216635
# min_variance   0.058282  0.104990  0.555119  0.684907    -0.269031  0.216635
# mean_variance  0.058819  0.105490  0.557574  0.723566    -0.279634  0.210341
# risk_parity    0.051251  0.127442  0.402150  0.439809    -0.337243  0.151971
# vol_target     0.050835  0.113562  0.447638  0.526402    -0.261231  0.194596
#
#                AvgTurnover  RealizedVol  VolMinusTarget     VaR95    CVaR95
# equal_weight      0.000331     0.104990        0.004990 -0.009855 -0.015698
# min_variance      0.000331     0.104990        0.004990 -0.009855 -0.015698
# mean_variance     0.013699     0.105490        0.005490 -0.010781 -0.016195
# risk_parity       0.026533     0.127442        0.027442 -0.010137 -0.018182
# vol_target        0.002383     0.113562        0.013562 -0.010447 -0.017149

# %%
res.returns.cumsum().tail()
# Out:
#             equal_weight  min_variance  mean_variance  risk_parity  vol_target
# Date
# 2024-12-24      0.756772      0.756772       0.768476     0.706964    0.684616
# 2024-12-26      0.757552      0.757552       0.770469     0.707812    0.685456
# 2024-12-27      0.749514      0.749514       0.760644     0.700597    0.676793
# 2024-12-30      0.745621      0.745621       0.751942     0.698313    0.672597
# 2024-12-31      0.744503      0.744503       0.751091     0.697017    0.671392
